# %% [markdown]
# #**Exploratory Data Analysis Pandas**

# %% [markdown]
# ##**Importing pandas , seaborn & matplotlib**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ##**Loading Datasets**

# %%
df1 = pd.read_excel('/content/drive/MyDrive/Data-Sciecne(Funcdamentals)/Data_Information_path/world_population_excel_workbook.xlsx')
df1
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara         El AaiÃºn    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0           41128771         38972230         33753499         28189672
# 1            2842321          2866849          2882481          2913399
# ...

# %%
df2 = df1.drop(columns=['race/ethnicity'])
df2
# Replaced 'parental ' with the correct column name 'parental level of education'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-cb9d497dad63> in <cell line: 1>()
# ----> 1 df2 = df1.drop(columns=['race/ethnicity'])
#       2 df2
#       3 # Replaced 'parental ' with the correct column name 'parental level of education'
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/Data-Sciecne(Funcdamentals)/Data_Information_path/online_sales_dataset.csv')
df
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01 00:00
# 1         771155  SKU_1241     White Mug        18  2020-01-01 01:00
# 2         231932  SKU_1501    Headphones        49  2020-01-01 02:00
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01 03:00
# 4         359178  SKU_1386     USB Cable       -30  2020-01-01 04:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  2025-09-05 01:00
# 49778     296698  SKU_1930     USB Cable         7  2025-09-05 02:00
# 49779     177622  SKU_1766  Office Chair        43  2025-09-05 03:00
# 49780     701213  SKU_1602      Notebook        48  2025-09-05 04:00
# 49781     772215  SKU_1832     White Mug        30  2025-09-05 05:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %% [markdown]
# ##**DataFrame Operations**

# %%
pd.set_option('display.float_format' , '{:.2f}'.format)

# %%
df
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01 00:00
# 1         771155  SKU_1241     White Mug        18  2020-01-01 01:00
# 2         231932  SKU_1501    Headphones        49  2020-01-01 02:00
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01 03:00
# 4         359178  SKU_1386     USB Cable       -30  2020-01-01 04:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  2025-09-05 01:00
# 49778     296698  SKU_1930     USB Cable         7  2025-09-05 02:00
# 49779     177622  SKU_1766  Office Chair        43  2025-09-05 03:00
# 49780     701213  SKU_1602      Notebook        48  2025-09-05 04:00
# 49781     772215  SKU_1832     White Mug        30  2025-09-05 05:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %%
df1.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (kmÂ²)                    0
# Density (per kmÂ²)             0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# InvoiceNo               0
# StockCode               0
# Description             0
# Quantity                0
# InvoiceDate             0
# UnitPrice               0
# CustomerID           4978
# Country                 0
# Discount                0
# PaymentMethod           0
# ShippingCost         2489
# Category                0
# SalesChannel            0
# ReturnStatus            0
# ShipmentProvider        0
# WarehouseLocation    3485
# OrderPriority           0
# dtype: int64

# %%
df1.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
df1.sort_values(by='Continent' , ascending=False)
# Out:
#      Rank CCA3           Country   Capital      Continent  2022 Population  \
# 27      7  BRA            Brazil  Brasilia  South America        215313498
# 227    51  VEN         Venezuela   Caracas  South America         28301696
# 162    44  PER              Peru      Lima  South America         34049588
# 64    231  FLK  Falkland Islands   Stanley  South America             3780
# 42     28  COL          Colombia    Bogota  South America         51874024
# ..    ...  ...               ...       ...            ...              ...
# 195    86  SSD       South Sudan      Juba         Africa         10913164
# 75     47  GHA             Ghana     Accra         Africa         33475870
# 198    32  SDN             Sudan  Khartoum         Africa         46874204
# 72    142  GMB            Gambia    Banjul         Africa          2705992
# 233    74  ZWE          Zimbabwe    Harare         Africa         16320537
#
# ...

# %%
df.sort_values('Quantity' , ascending=False)
# Out:
#        InvoiceNo StockCode     Description  Quantity       InvoiceDate  \
# 16596     197204  SKU_1123        Blue Pen        49  2021-11-22 12:00
# 34929     619521  SKU_1225        Blue Pen        49  2023-12-26 09:00
# 16962     932441  SKU_1988       USB Cable        49  2021-12-07 18:00
# 29261     377264  SKU_1237       USB Cable        49  2023-05-04 05:00
# 45553     298157  SKU_1104        Notebook        49  2025-03-13 01:00
# ...          ...       ...             ...       ...               ...
# 34067     482323  SKU_1363         T-shirt       -50  2023-11-20 11:00
# 3085      521486  SKU_1199  Wireless Mouse       -50  2020-05-08 13:00
# 15204     131912  SKU_1812       USB Cable       -50  2021-09-25 12:00
# 6211      915869  SKU_1610       Desk Lamp       -50  2020-09-15 19:00
# 29668     795047  SKU_1932      Headphones       -50  2023-05-21 04:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %%
df1.sort_values(['Capital' , 'Rank'] , ascending = False).head(10).agg({'Growth Rate' : ['sum' , 'count' , 'mean']})
# Out:
#        Growth Rate
# sum       10.12640
# count     10.00000
# mean       1.01264

# %%
df.sort_values('ShippingCost' , ascending =False).head(10).agg({'ShippingCost':'sum' , 'mean' ,  })
# Out:
# ShippingCost   300.00
# dtype: float64

# %%
df.sort_values('Quantity' , ascending=False).head(6)
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 16596     197204  SKU_1123      Blue Pen        49  2021-11-22 12:00
# 34929     619521  SKU_1225      Blue Pen        49  2023-12-26 09:00
# 16962     932441  SKU_1988     USB Cable        49  2021-12-07 18:00
# 29261     377264  SKU_1237     USB Cable        49  2023-05-04 05:00
# 45553     298157  SKU_1104      Notebook        49  2025-03-13 01:00
# 8954      257699  SKU_1827  Office Chair        49  2021-01-08 02:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# 16596      90.21    74357.00           Italy      0.17        paypall
# 34929      19.86    72673.00         Germany      0.49        paypall
# 16962      30.30    82342.00  United Kingdom      0.46  Bank Transfer
# 29261      52.56    57185.00         Belgium      0.19        paypall
# 45553      74.22    89983.00           Italy      0.25    Credit Card
# ...

# %%
df1.sort_values(by='World Population Percentage' , ascending = False).head(10)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 149     6  NGA        Nigeria             Abuja         Africa
# 27      7  BRA         Brazil          Brasilia  South America
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# ...

# %%
df2 = df.describe()
df2.corr()
# Out:
#               InvoiceNo  Quantity  UnitPrice  CustomerID  Discount  \
# InvoiceNo      1.000000 -0.490514  -0.489246    0.904998 -0.491715
# Quantity      -0.490514  1.000000   0.999999   -0.073227  0.999999
# UnitPrice     -0.489246  0.999999   1.000000   -0.071776  0.999994
# CustomerID     0.904998 -0.073227  -0.071776    1.000000 -0.074601
# Discount      -0.491715  0.999999   0.999994   -0.074601  1.000000
# ShippingCost  -0.491310  0.999999   0.999996   -0.074137  1.000000
#
#               ShippingCost
# InvoiceNo        -0.491310
# Quantity          0.999999
# UnitPrice         0.999996
# CustomerID       -0.074137
# Discount          1.000000
# ShippingCost      1.000000

# %%
df2.isnull().sum()
# Out:
# InvoiceNo       0
# Quantity        0
# UnitPrice       0
# CustomerID      0
# Discount        0
# ShippingCost    0
# dtype: int64

# %%
df.sort_values(by='Discount' , ascending = False).head(10)
# Out:
#        InvoiceNo StockCode     Description  Quantity       InvoiceDate  \
# 38189     773527  SKU_1057        Backpack       -38  2024-05-10 05:00
# 48065     231190  SKU_1908         T-shirt       -43  2025-06-25 17:00
# 24056     496713  SKU_1540        Blue Pen       -22  2022-09-29 08:00
# 23323     183804  SKU_1581    Office Chair       -11  2022-08-29 19:00
# 48035     448355  SKU_1046  Wireless Mouse       -28  2025-06-24 11:00
# 43007     500075  SKU_1246        Notebook        -7  2024-11-26 23:00
# 37363     651763  SKU_1869       USB Cable       -22  2024-04-05 19:00
# 508       804107  SKU_1386        Notebook        -5  2020-01-22 04:00
# 27003     679437  SKU_1567  Wireless Mouse        -1  2023-01-30 03:00
# 7687      510226  SKU_1621  Wireless Mouse       -44  2020-11-16 07:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# 38189      -5.90         NaN           Spain  1.999764  Bank Transfer
# ...

# %%
df2.corr()
# Out:
#               InvoiceNo  Quantity  UnitPrice  CustomerID  Discount  \
# InvoiceNo      1.000000 -0.490514  -0.489246    0.904998 -0.491715
# Quantity      -0.490514  1.000000   0.999999   -0.073227  0.999999
# UnitPrice     -0.489246  0.999999   1.000000   -0.071776  0.999994
# CustomerID     0.904998 -0.073227  -0.071776    1.000000 -0.074601
# Discount      -0.491715  0.999999   0.999994   -0.074601  1.000000
# ShippingCost  -0.491310  0.999999   0.999996   -0.074137  1.000000
#
#               ShippingCost
# InvoiceNo        -0.491310
# Quantity          0.999999
# UnitPrice         0.999996
# CustomerID       -0.074137
# Discount          1.000000
# ShippingCost      1.000000

# %%
sns.heatmap(df2.corr() , annot=True)

plt.rcParams['figure.figsize'] = (20,8)

plt.show()

# %%
df[df['Country'].str.contains('America')].sort_values(by='Country' , ascending=True)
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, Discount, PaymentMethod, ShippingCost, Category, SalesChannel, ReturnStatus, ShipmentProvider, WarehouseLocation, OrderPriority]
# Index: []

# %%
df.plot()
# Out:
# <Axes: >

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df3 = df2.transpose()
df3
# Out:
#                 count           mean            std        min          25%  \
# InvoiceNo     49782.0  550681.239946  260703.009944  100005.00  324543.0000
# Quantity      49782.0      22.372343      17.917774     -50.00      11.0000
# UnitPrice     49782.0      47.537862      33.479510     -99.98      23.5925
# CustomerID    44804.0   55032.871775   25913.660157   10001.00   32750.7500
# Discount      49782.0       0.275748       0.230077       0.00       0.1300
# ShippingCost  47293.0      17.494529       7.220557       5.00      11.2200
#
#                     50%        75%            max
# InvoiceNo     552244.00  776364.00  999997.000000
# Quantity          23.00      37.00      49.000000
# UnitPrice         48.92      74.61     100.000000
# CustomerID     55165.00   77306.25   99998.000000
# Discount           0.26       0.38       1.999764
# ShippingCost      17.50      23.72      30.000000

# %%
df3.plot()
# Out:
# <Axes: >

# %%
df2 = df1.columns[5:16]

# %%
df2
# Out:
# Index(['2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (kmÂ²)',
#        'Density (per kmÂ²)', 'Growth Rate'],
#       dtype='object')

# %%
df_3 = df1.groupby('Continent')[df1.columns[5:16]].mean().sort_values(by='2022 Population' , ascending=False)
df_3
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Asia              9.442767e+07     9.326173e+07     8.916500e+07
# South America     3.120119e+07     3.082357e+07     2.950960e+07
# Africa            2.503037e+07     2.387144e+07     2.107197e+07
# North America     1.500740e+07     1.485591e+07     1.425960e+07
# Europe            1.486295e+07     1.491584e+07     1.483071e+07
# Oceania           1.958198e+06     1.910149e+06     1.756664e+06
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia              8.440083e+07     7.470179e+07     6.421127e+07
# South America     2.807702e+07     2.497388e+07     2.122474e+07
# Africa            1.851277e+07     1.436747e+07     1.119563e+07
# North America     1.356802e+07     1.215174e+07     1.053166e+07
# Europe            1.471228e+07     1.452187e+07     1.440642e+07
# Oceania           1.613164e+06     1.357512e+06     1.162775e+06
#
# ...

# %%
df_3.plot(kind='line')
# Out:
# <Axes: xlabel='Continent'>

# %%
df_3.boxplot()
# Out:
# <Axes: >
