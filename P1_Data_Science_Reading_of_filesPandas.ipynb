# %% [markdown]
# <a href="https://colab.research.google.com/github/syedabdullahbukhari77/Pandas_Data_Science/blob/main/P1_Data_Science_Reading_of_filesPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()
import pandas as pd

# %%
df2 = pd.read_csv('/content/organizations-100.csv')
display(df2)
# Out:
#     Index  Organization Id  ...                     Industry  \
# 0       1  FAB0d41d5b5d22c  ...                     Plastics
# 1       2  6A7EdDEA9FaDC52  ...  Glass / Ceramics / Concrete
# ..    ...              ...  ...                          ...
# 98     99  AFc285dbE2fEd24  ...         Education Management
# 99    100  e9eB5A60Cef8354  ...           Financial Services
#
#    Number of employees
# 0                 3498
# 1                 4952
# ..                 ...
# 98                 339
# 99                2785
#
# [100 rows x 9 columns]

# %%
df2.shape
# Out:
# (100, 9)

# %%
df2.head(10)
# Out:
#     Index  Organization Id  ...                     Industry  \
# 0       1  FAB0d41d5b5d22c  ...                     Plastics
# 1       2  6A7EdDEA9FaDC52  ...  Glass / Ceramics / Concrete
# ..    ...              ...  ...                          ...
# 8       9  0B4F93aA06ED03e  ...                     Plastics
# 9      10  738b5aDe6B1C6A5  ...     Outsourcing / Offshoring
#
#    Number of employees
# 0                 3498
# 1                 4952
# ..                 ...
# 8                 8167
# 9                 9698
#
# [10 rows x 9 columns]

# %%
df2['Industry'], df2['Industry'].unique()
# Out:
# (0                        Plastics
#  1     Glass / Ceramics / Concrete
#                   ...
#  98           Education Management
#  99             Financial Services
#  Name: Industry, Length: 100, dtype: object,
#  array(['Plastics', 'Glass / Ceramics / Concrete', 'Public Safety',
#         'Automotive', 'Transportation', 'Primary / Secondary Education',
#         'Publishing Industry', 'Import / Export',
#         'Outsourcing / Offshoring', 'Food / Beverages',
#         'Museums / Institutions', 'Medical Practice', 'Maritime',
#         'Facilities Services',
#         'Investment Management / Hedge Fund / Private Equity',
#         'Architecture / Planning', 'Wholesale', 'Construction',
#         'Luxury Goods / Jewelry', 'Pharmaceuticals', 'Insurance',
#         'Real Estate / Mortgage', 'Banking / Mortgage', 'Legal Services',
#         'Logistics / Procurement', 'Civil Engineering',
#         'Mechanical or Industrial Engineering', 'Hospitality',
# ...
