# %% [markdown]
# #**Data Cleaning**

# %% [markdown]
# ##**Importing Pandas Library**

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##**Loading Datasets**

# %%
df = pd.read_csv('/content/drive/MyDrive/Data-Sciecne(Funcdamentals)/Data_Information_path/online_sales_dataset.csv')
df
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01 00:00
# 1         771155  SKU_1241     White Mug        18  2020-01-01 01:00
# 2         231932  SKU_1501    Headphones        49  2020-01-01 02:00
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01 03:00
# 4         359178  SKU_1386     USB Cable       -30  2020-01-01 04:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  2025-09-05 01:00
# 49778     296698  SKU_1930     USB Cable         7  2025-09-05 02:00
# 49779     177622  SKU_1766  Office Chair        43  2025-09-05 03:00
# 49780     701213  SKU_1602      Notebook        48  2025-09-05 04:00
# 49781     772215  SKU_1832     White Mug        30  2025-09-05 05:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %% [markdown]
# ##**Duplicates**

# %%
duplicates = df.duplicated()
duplicates
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49777    False
# 49778    False
# 49779    False
# 49780    False
# 49781    False
# Length: 49782, dtype: bool

# %% [markdown]
# ##**Drop Duplicates**

# %%
drop_duplicates = df.drop_duplicates()
drop_duplicates
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01 00:00
# 1         771155  SKU_1241     White Mug        18  2020-01-01 01:00
# 2         231932  SKU_1501    Headphones        49  2020-01-01 02:00
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01 03:00
# 4         359178  SKU_1386     USB Cable       -30  2020-01-01 04:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  2025-09-05 01:00
# 49778     296698  SKU_1930     USB Cable         7  2025-09-05 02:00
# 49779     177622  SKU_1766  Office Chair        43  2025-09-05 03:00
# 49780     701213  SKU_1602      Notebook        48  2025-09-05 04:00
# 49781     772215  SKU_1832     White Mug        30  2025-09-05 05:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %% [markdown]
# ##**Drop Columns**

# %%
Drop_Columns = df.drop(columns = 'StockCode')
Drop_Columns
# Out:
#        InvoiceNo   Description  Quantity       InvoiceDate  UnitPrice  \
# 0         221958     White Mug        38  2020-01-01 00:00       1.71
# 1         771155     White Mug        18  2020-01-01 01:00      41.25
# 2         231932    Headphones        49  2020-01-01 02:00      29.11
# 3         465838     Desk Lamp        14  2020-01-01 03:00      76.68
# 4         359178     USB Cable       -30  2020-01-01 04:00     -68.11
# ...          ...           ...       ...               ...        ...
# 49777     354083      Blue Pen        25  2025-09-05 01:00      70.92
# 49778     296698     USB Cable         7  2025-09-05 02:00      51.74
# 49779     177622  Office Chair        43  2025-09-05 03:00      85.25
# 49780     701213      Notebook        48  2025-09-05 04:00      39.64
# 49781     772215     White Mug        30  2025-09-05 05:00      38.27
#
#        CustomerID         Country  Discount  PaymentMethod  ShippingCost  \
# ...

# %% [markdown]
# ##**Stripping**

# %%
df['Category'].str.strip()
# Out:
# 0            Apparel
# 1        Electronics
# 2        Electronics
# 3        Accessories
# 4        Electronics
#             ...
# 49777    Electronics
# 49778    Electronics
# 49779      Furniture
# 49780        Apparel
# 49781     Stationery
# Name: Category, Length: 49782, dtype: object

# %%
df['Category'].str.lstrip()
# Out:
# 0            Apparel
# 1        Electronics
# 2        Electronics
# 3        Accessories
# 4        Electronics
#             ...
# 49777    Electronics
# 49778    Electronics
# 49779      Furniture
# 49780        Apparel
# 49781     Stationery
# Name: Category, Length: 49782, dtype: object

# %% [markdown]
# ##**str.split Function**
#
# >`split()`

# %%
df['Country'].str.split(',' , n=1 , expand = True)
# Out:
#                     0
# 0           Australia
# 1               Spain
# 2             Germany
# 3         Netherlands
# 4      United Kingdom
# ...               ...
# 49777           Spain
# 49778   United States
# 49779        Portugal
# 49780  United Kingdom
# 49781          France
#
# [49782 rows x 1 columns]

# %%
df[['Country']] = df['Country'].str.split(',' , n=2 , expand = True)
df[['Country']]
# Out:
#               Country
# 0           Australia
# 1               Spain
# 2             Germany
# 3         Netherlands
# 4      United Kingdom
# ...               ...
# 49777           Spain
# 49778   United States
# 49779        Portugal
# 49780  United Kingdom
# 49781          France
#
# [49782 rows x 1 columns]

# %% [markdown]
# ##**Renaming Columns**

# %%
df = df.rename(columns = {'Country':'Country_Name'})
df
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01 00:00
# 1         771155  SKU_1241     White Mug        18  2020-01-01 01:00
# 2         231932  SKU_1501    Headphones        49  2020-01-01 02:00
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01 03:00
# 4         359178  SKU_1386     USB Cable       -30  2020-01-01 04:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  2025-09-05 01:00
# 49778     296698  SKU_1930     USB Cable         7  2025-09-05 02:00
# 49779     177622  SKU_1766  Office Chair        43  2025-09-05 03:00
# 49780     701213  SKU_1602      Notebook        48  2025-09-05 04:00
# 49781     772215  SKU_1832     White Mug        30  2025-09-05 05:00
#
#        UnitPrice  CustomerID    Country_Name  Discount  PaymentMethod  \
# ...

# %%
df = df.rename(columns = {'PaymentMethod':'Payment_Method'})
df
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01 00:00
# 1         771155  SKU_1241     White Mug        18  2020-01-01 01:00
# 2         231932  SKU_1501    Headphones        49  2020-01-01 02:00
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01 03:00
# 4         359178  SKU_1386     USB Cable       -30  2020-01-01 04:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  2025-09-05 01:00
# 49778     296698  SKU_1930     USB Cable         7  2025-09-05 02:00
# 49779     177622  SKU_1766  Office Chair        43  2025-09-05 03:00
# 49780     701213  SKU_1602      Notebook        48  2025-09-05 04:00
# 49781     772215  SKU_1832     White Mug        30  2025-09-05 05:00
#
#        UnitPrice  CustomerID    Country_Name  Discount Payment_Method  \
# ...
