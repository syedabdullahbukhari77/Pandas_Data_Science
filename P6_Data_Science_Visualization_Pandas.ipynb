# %% [markdown]
# #**Pandas Visualization**

# %% [markdown]
# ##**Importing Pandas Library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive

# %% [markdown]
# ##**Loading Datasets**

# %%
df = pd.read_csv('/content/drive/MyDrive/Data-Sciecne(Funcdamentals)/Data_Information_path/online_sales_dataset.csv')
df
# Out:
#        InvoiceNo StockCode   Description  Quantity       InvoiceDate  \
# 0         221958  SKU_1964     White Mug        38  2020-01-01 00:00
# 1         771155  SKU_1241     White Mug        18  2020-01-01 01:00
# 2         231932  SKU_1501    Headphones        49  2020-01-01 02:00
# 3         465838  SKU_1760     Desk Lamp        14  2020-01-01 03:00
# 4         359178  SKU_1386     USB Cable       -30  2020-01-01 04:00
# ...          ...       ...           ...       ...               ...
# 49777     354083  SKU_1562      Blue Pen        25  2025-09-05 01:00
# 49778     296698  SKU_1930     USB Cable         7  2025-09-05 02:00
# 49779     177622  SKU_1766  Office Chair        43  2025-09-05 03:00
# 49780     701213  SKU_1602      Notebook        48  2025-09-05 04:00
# 49781     772215  SKU_1832     White Mug        30  2025-09-05 05:00
#
#        UnitPrice  CustomerID         Country  Discount  PaymentMethod  \
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Data-Sciecne(Funcdamentals)/Data_Information_path/StudentsPerformance.csv')
df2
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ###**New Dataframe from Old One**

# %%
n_df = df2[['math score' , 'reading score' , 'writing score']]
n_df
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %% [markdown]
# ###**Setting up Index**

# %%
df.set_index('InvoiceNo')
# Out:
#           StockCode   Description  Quantity       InvoiceDate  UnitPrice  \
# InvoiceNo
# 221958     SKU_1964     White Mug        38  2020-01-01 00:00       1.71
# 771155     SKU_1241     White Mug        18  2020-01-01 01:00      41.25
# 231932     SKU_1501    Headphones        49  2020-01-01 02:00      29.11
# 465838     SKU_1760     Desk Lamp        14  2020-01-01 03:00      76.68
# 359178     SKU_1386     USB Cable       -30  2020-01-01 04:00     -68.11
# ...             ...           ...       ...               ...        ...
# 354083     SKU_1562      Blue Pen        25  2025-09-05 01:00      70.92
# 296698     SKU_1930     USB Cable         7  2025-09-05 02:00      51.74
# 177622     SKU_1766  Office Chair        43  2025-09-05 03:00      85.25
# 701213     SKU_1602      Notebook        48  2025-09-05 04:00      39.64
# 772215     SKU_1832     White Mug        30  2025-09-05 05:00      38.27
#
#            CustomerID         Country  Discount  PaymentMethod  ShippingCost  \
# ...

# %% [markdown]
# ##**Visualization**

# %% [markdown]
# ###**Pie Chart**

# %%
n_df.plot.pie(y='reading score', labels=n_df['math score'], autopct='%1.1f%%')
# Out:
# <Axes: ylabel='reading score'>

# %% [markdown]
# ###**Column**

# %%
df.plot(kind = 'area')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-2fe8c97749b3> in <cell line: 1>()
# ----> 1 df.plot(kind = 'area')
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#    1028                     data.columns = label_name
#    1029
# -> 1030         return plot_backend.plot(data, kind=kind, **kwargs)
#    1031
#    1032     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
# ...

# %% [markdown]
# ###**Line Chart**

# %%
df.plot(kind='line')
# Out:
# <Axes: >

# %%
n_df.plot(stacked = True  , subplots = True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
n_df.plot(kind = 'line' , title = 'Students Data' , xlabel = 'x-plot', ylabel = 'y-plot')
# Out:
# <Axes: title={'center': 'Students Data'}, xlabel='x-plot', ylabel='y-plot'>

# %%
n_df1 = n_df[['reading score' , 'writing score']]
n_df1.plot(kind = 'line' , title = 'Students Data' , xlabel = 'x-plot', ylabel = 'y-plot')
# Out:
# <Axes: title={'center': 'Students Data'}, xlabel='x-plot', ylabel='y-plot'>

# %%
df.plot(kind='line' , subplots = True , title = "Syed's Sheet" , xlabel = 'InvoiceNo' , ylabel = 'Price')
# Out:
# array([<Axes: xlabel='InvoiceNo', ylabel='Price'>,
#        <Axes: xlabel='InvoiceNo', ylabel='Price'>,
#        <Axes: xlabel='InvoiceNo', ylabel='Price'>,
#        <Axes: xlabel='InvoiceNo', ylabel='Price'>,
#        <Axes: xlabel='InvoiceNo', ylabel='Price'>,
#        <Axes: xlabel='InvoiceNo', ylabel='Price'>], dtype=object)

# %% [markdown]
# ###**Histogram**

# %%
n_df.plot(kind = 'hist' , subplots = True)
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>], dtype=object)

# %%
n_df.plot.hist(bins = 20 , alpha = 0.5)

# %% [markdown]
# ###**Histogram Chart**

# %%
df[['ShippingCost' , 'Quantity']].plot(kind = 'hist' , title = "Syed's Sheet")
# Out:
# <Axes: title={'center': "Syed's Sheet"}, ylabel='Frequency'>

# %% [markdown]
# ###**Bar Chart**

# %%
df.plot(kind = 'bar' , stacked = True)

# %% [markdown]
# ###**Stacked One**

# %%
df2.plot.barh(stacked = True)
# Out:
# <Axes: >

# %%
df[['ShippingCost' , 'Quantity']].plot.bar(stacked = True)
# Out:
# <Axes: >

# %%
df[['Quantity' , 'UnitPrice']].plot.bar(stacked = True)
# Out:
# <Axes: >

# %% [markdown]
# ###**Box Chart**

# %%
df['Quantity'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
n_df.plot.box()
n_df.plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# ###**Scatter Chart**

# %%
df.plot.scatter(x = 'Discount' , y = 'UnitPrice')
# Out:
# <Axes: xlabel='Discount', ylabel='UnitPrice'>
